# %%
from jcamp import JCAMP_reader
import matplotlib.pyplot as plt

# %%
import supercollider
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15328/31832534.py in <module>
# ----> 1 import supercollider
#
# ModuleNotFoundError: No module named 'supercollider'

# %%
filename = 'acetone-IR.jdx'
jcamp_dict = JCAMP_reader(filename)
plt.plot(jcamp_dict['x'], jcamp_dict['y'])
plt.title(filename)
plt.xlabel(jcamp_dict['xunits'])
plt.ylabel(jcamp_dict['yunits'])
# Out:
# Text(0, 0.5, 'TRANSMITTANCE')

# %%
filename = 'acetone-UVVis.jdx'
jcamp_dict = JCAMP_reader(filename)
plt.plot(jcamp_dict['x'], jcamp_dict['y'])
plt.title(filename)
plt.xlabel(jcamp_dict['xunits'])
plt.ylabel(jcamp_dict['yunits'])
# Out:
# Text(0, 0.5, 'Logarithm epsilon')
